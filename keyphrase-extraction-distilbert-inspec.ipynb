# %%
# !pip install datasets
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 7.5 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.2 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 20.7 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 14.6 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.4 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 46.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.3 transformers-4.28.1

# %%
import datasets as ds

# %%
data=ds.load_dataset("midas/inspec")
# Out:
# Downloading builder script:   0%|          | 0.00/6.47k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/25.4k [00:00<?, ?B/s]
# WARNING:datasets.builder:No config specified, defaulting to: inspec/extraction
# Downloading and preparing dataset inspec/extraction to /root/.cache/huggingface/datasets/midas___inspec/extraction/0.0.1/debd18641afb7048a36cee2b7bb8dfbf2cd1a68899118653a42fd760cf84284e...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.40M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.13M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset inspec downloaded and prepared to /root/.cache/huggingface/datasets/midas___inspec/extraction/0.0.1/debd18641afb7048a36cee2b7bb8dfbf2cd1a68899118653a42fd760cf84284e. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

# Tokenizer
tokenizer = AutoTokenizer.from_pretrained("bloomberg/KeyBART", add_prefix_space=True)

# Dataset parameters
dataset_full_name = "midas/inspec"
dataset_subset = "raw"
dataset_document_column = "document"

keyphrase_sep_token = ";"

def preprocess_keyphrases(text_ids, kp_list):
    kp_order_list = []
    kp_set = set(kp_list)
    text = tokenizer.decode(
        text_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True
    )
    text = text.lower()
    for kp in kp_set:
        kp = kp.strip()
        kp_index = text.find(kp.lower())
        kp_order_list.append((kp_index, kp))

    kp_order_list.sort()
    present_kp, absent_kp = [], []

    for kp_index, kp in kp_order_list:
        if kp_index < 0:
            absent_kp.append(kp)
        else:
            present_kp.append(kp)
    return present_kp, absent_kp


def preprocess_fuction(samples):
    processed_samples = {"input_ids": [], "attention_mask": [], "labels": []}
    for i, sample in enumerate(samples[dataset_document_column]):
        input_text = " ".join(sample)
        inputs = tokenizer(
            input_text,
            padding="max_length",
            truncation=True,
        )
        present_kp, absent_kp = preprocess_keyphrases(
            text_ids=inputs["input_ids"],
            kp_list=samples["extractive_keyphrases"][i]
            + samples["abstractive_keyphrases"][i],
        )
        keyphrases = present_kp
        keyphrases += absent_kp

        target_text = f" {keyphrase_sep_token} ".join(keyphrases)

        with tokenizer.as_target_tokenizer():
            targets = tokenizer(
                target_text, max_length=40, padding="max_length", truncation=True
            )
            targets["input_ids"] = [
                (t if t != tokenizer.pad_token_id else -100)
                for t in targets["input_ids"]
            ]
        for key in inputs.keys():
            processed_samples[key].append(inputs[key])
        processed_samples["labels"].append(targets["input_ids"])
    return processed_samples

# Load dataset
dataset = load_dataset(dataset_full_name, dataset_subset)
# Preprocess dataset
tokenized_dataset = dataset.map(preprocess_fuction, batched=True)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.69k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading and preparing dataset inspec/raw to /root/.cache/huggingface/datasets/midas___inspec/raw/0.0.1/debd18641afb7048a36cee2b7bb8dfbf2cd1a68899118653a42fd760cf84284e...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset inspec downloaded and prepared to /root/.cache/huggingface/datasets/midas___inspec/raw/0.0.1/debd18641afb7048a36cee2b7bb8dfbf2cd1a68899118653a42fd760cf84284e. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:3596: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
train=tokenized_dataset['train']
test=tokenized_dataset['test']
val=tokenized_dataset['validation']

# %%
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'document', 'doc_bio_tags', 'extractive_keyphrases', 'abstractive_keyphrases', 'other_metadata', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
#     test: Dataset({
#         features: ['id', 'document', 'doc_bio_tags', 'extractive_keyphrases', 'abstractive_keyphrases', 'other_metadata', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 500
#     })
#     validation: Dataset({
#         features: ['id', 'document', 'doc_bio_tags', 'extractive_keyphrases', 'abstractive_keyphrases', 'other_metadata', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 500
#     })
# })

# %%
train_document=[" ".join(i['document']) for i in train]
train_keyphrase=[i['extractive_keyphrases'] for i in train]

test_document=[" ".join(i['document']) for i in test]
test_keyphrase=[i['extractive_keyphrases'] for i in test]

val_document=[" ".join(i['document']) for i in val]
val_keyphrase=[i['extractive_keyphrases'] for i in val]

# %%
from transformers import (
    TokenClassificationPipeline,
    AutoModelForTokenClassification,
    AutoTokenizer,
)
from transformers.pipelines import AggregationStrategy
import numpy as np

# Define keyphrase extraction pipeline
class KeyphraseExtractionPipeline(TokenClassificationPipeline):
    def __init__(self, model, *args, **kwargs):
        super().__init__(
            model=AutoModelForTokenClassification.from_pretrained(model),
            tokenizer=AutoTokenizer.from_pretrained(model),
            *args,
            **kwargs
        )

    def postprocess(self, model_outputs):
        results = super().postprocess(
            model_outputs,
            aggregation_strategy=AggregationStrategy.FIRST,
        )
        return np.unique([result.get("word").strip() for result in results])


# Load pipeline
model_name = "ml6team/keyphrase-extraction-distilbert-inspec"
extractor = KeyphraseExtractionPipeline(model=model_name)

# %%
keyphrases = extractor(test_document)
print(keyphrases)
# Out:
# [array(['biological tissues', 'calculational speed', 'calibration',
#        'computation phantoms', 'computational phantoms',
#        'computed tomography', 'data analysis', 'energy', 'gamma ray',
#        'graphical user interface', 'in vivo measurement systems',
#        'in vivo measurements', 'low energy emitters',
#        'magnetic resonance imaging',
#        'magnetic resonance imaging scanning information',
#        'mcnp calculations', 'mcnp input', 'memory demand',
#        'monte carlo calculations', 'radionuclides'], dtype='<U47'), array(['accidents', 'balance weights', 'binocular charge coupled devices',
#        'bridge crack inspection', 'bridge crack inspection process',
#        'bridge crack inspections', 'bridge inspection vehicle',
#        'bridge safety inspections', 'ccd cameras', 'eyesight inspection',
#        'human inspectors', 'manipulator', 'mobile manipulator imaging',
#        'mobile manipulator imaging system', 'mobile vehicle',
#        'parallel cameras', 'scaffolding'], dtype='<U33'), array(['linear equations', 'safe problem'], dtype='<U16'), array(['communication cost', 'costs', 'html', 'hypertext markup language',
#        'intelligent wap site management system', 'keywords',
#        'manpower costs', 'mobile phone screens', 'numerals',
#        'numerical results', 'system manager', 'web sites',
#        'wireless communications', 'wireless markup language', 'wml'],
#       dtype='<U38'), array(['airy stress function', 'density distribution profile',
#        'density functionally gradient piezoelectric cantilever',
#        'induction functions', 'inverse method', 'loading conditions',
#        'piezoelectric cantilever', 'piezoelectric cantilever actuator',
#        'piezoelectric material', 'plane strain theory', 'stress',
#        'tip deflection', 'transversely isotropic bodies'], dtype='<U54'), array(['boolean', 'boolean functions', 'decomposition clone',
#        'disjunctive decomposition', 'minterms', 'partial functions',
#        'repeated decomposition'], dtype='<U25'), array(['bms', 'building management systems', 'building performance',
#        'questionnaire survey', 'technology acceptance', 'user acceptance',
#        'user perceptions', 'voluntariness'], dtype='<U27'), array(['computational discretization schemes', 'conjugate conditions',
#        'conjugation conditions', 'distributed systems',
#        'elliptic equations', 'quadratic minimized function', 'system'],
#       dtype='<U36'), array(['complex systems', 'formal system representation',
#        'systemological analysis'], dtype='<U28'), array(['certificate authorization', 'contract development tools',
#        'electronic devices', 'electronic government procurement system',
#        'electronic government procurement system functions',
#        'electronic tendering', 'government procurement',
#        'internal procurement processes', 'internet', 'nondiscriminating',
#        'online bidding', 'online payment', 'taiwan',
#        'taiwan government procurement law', 'vendor registration'],
#       dtype='<U50'), array(['admissible measurement errors', 'complex systems',
#        'fuzzy information', 'fuzzy set theory', 'fuzzy values',
#        'maximally admissible degree'], dtype='<U29'), array(['linear algebraic equations'], dtype='<U26'), array(['bms', 'building management system', 'building management systems',
#        'control', 'database integration', 'dcom',
#        'distributed component object model', 'embedded web server',
#        'facilities management systems', 'fms', 'interconnecting',
#        'internet protocols', 'local networks', 'open control network',
#        'pc web server'], dtype='<U34'), array(['collective dose', 'collective dose calculations',
#        'electronic population data resources',
#        'geographic information system software', 'personal computer'],
#       dtype='<U38'), array(['accelerated simulation', 'non - markovian systems'], dtype='<U23'), array(['abstraction', 'bipolar function', 'descriptive process',
#        'descriptological foundations', 'descriptological operations',
#        'intensional concept', 'programming descriptological foundations'],
#       dtype='<U40'), array(['linear constraints', 'linear diophantine equations',
#        'minimal generating sets', 'natural numbers criteria',
#        'nonstrict inequations', 'strict inequations', 'upper bounds'],
#       dtype='<U28'), array(['collections'], dtype='<U11'), array(['bayesian approach', 'bayesian decision procedure',
#        'fuzzy bayesian', 'fuzzy bayesian inference techniques',
#        'fuzzy data', 'pseudofuzzy quantities'], dtype='<U35'), array(['books on demand', 'loan requests', 'pilot project',
#        'staff perceptions', 'statistics'], dtype='<U17'), array(['nonlinear extrapolation', 'nonlinear extrapolation algorithm',
#        'nonlinear random dependences', 'scalar random process'],
#       dtype='<U33'), array(['adaptive vector channel allocation', 'broadband wireline',
#        'channel estimation', 'channel quality', 'channel spectral nulls',
#        'cyclic prefix insertion', 'frobenius norm metrics',
#        'high data rate transmission', 'multiple frequency bands',
#        'orthogonal frequency division multiplexing', 'scalable',
#        'scalable video transmission', 'severe intersymbol interference',
#        'system', 'transmission', 'transmission quality',
#        'vector channels', 'wireless channels', 'wireless systems'],
#       dtype='<U42'), array(['music publishing', 'performance', 'technical music'], dtype='<U16'), array(['lower bounds'], dtype='<U12'), array(['constituent businesses', 'firm growth rates',
#        'independent businesses', 'integers', 'large firms'], dtype='<U22'), array(['control center', 'control center infrastructure',
#        'control center infrastructures', 'electric service',
#        'energy management system', 'energy market', 'market rules',
#        'reliability', 'security', 'security control'], dtype='<U30'), array(['dynamic pricing', 'dynamic pricing model', 'information',
#        'internet based mediums', 'internet usage', 'lodging industry',
#        'lodging industry profit margins', 'market pricing',
#        'online auctions', 'online intermediaries',
#        'overnight accommodation', 'pricing',
#        'product distribution channels', 'specialty brokers',
#        'supply chain', 'web site scripting'], dtype='<U31'), array(['effective synchronous generator', 'optimal linear control', 'pss',
#        'stabilizer design', 'synchronous generator',
#        'system operating conditions'], dtype='<U31'), array(['applications', 'computer applications', 'deregulation',
#        'electric power industry', 'vast networked information systems'],
#       dtype='<U34'), array(['cs atoms', 'gaussian states', 'ground state spin',
#        'quadrature phase observables', 'quadrature phase operators',
#        'quantum memory', 'quantum properties', 'quantum state',
#        'squeezed states'], dtype='<U28'), array(['artifacts', 'decorrelated', 'diagnostic relevance',
#        'discrete wavelet transform', 'disjoint segments',
#        'embedded zerotree coding', 'filter length',
#        'head magnetic resonance images', 'lossless coding',
#        'multidimensional layered zero coding', 'rate allocation',
#        'region boundaries', 'region of interest', 'volumetric data'],
#       dtype='<U36'), array(['class membership', 'classification performance',
#        'experts classification', 'experts classifier', 'external cluster',
#        'hierarchical mixture model', 'internal class',
#        'maximum likelihood', 'posterior probability', 'the'], dtype='<U26'), array(['additive scheme', 'content descriptor', 'correlation properties',
#        'delaunay tessellation', 'digital images', 'enhanced detector',
#        'feature points', 'geometrical distortions',
#        'geometrical transformations',
#        'geometrically invariant watermarking', 'global transformations',
#        'image content', 'local transformations', 'periodical properties',
#        'stirmark attack', 'tessellation', 'triangles', 'watermarking',
#        'watermarking methods', 'watermarking schemes'], dtype='<U36'), array(['enterprise application integration', 'software applications'],
#       dtype='<U34'), array(['absolute zerotree', 'coding process', 'common requirement',
#        'dsp chip', 'dsp solution', 'error bits',
#        'hardware implementation', 'hierarchical trees', 'memory cost',
#        'program structure', 'spiht algorithm', 'wavelet decomposition',
#        'wavelet transform', 'zerotree quantization'], dtype='<U23'), array(['dynamical behavior', 'dynamical transition',
#        'dynamical transitions', 'nonlinear map', 'nonstops',
#        'periodic behaviors', 'periodic motions', 'recurrent bus',
#        'recurrent time'], dtype='<U21'), array(['controllers', 'integrated absolute error',
#        'integrating processes', 'pi', 'robustness', 'sensitivity',
#        'sensitivity function', 'step load disturbance'], dtype='<U25'), array(['accumulation moments', 'convolution', 'convolving',
#        'edge detection', 'local geometric moments', 'matrix formulation',
#        'neighborhood operation', 'overlapping windows',
#        'texture segmentation', 'uncorrelated noise'], dtype='<U23'), array(['adaptive robust stabilization',
#        'adaptive robust state feedback control scheme',
#        'adaptive robust state feedback controller',
#        'adaptive state feedback control', 'linear systems',
#        'nonlinear uncertainties', 'uncertain dynamical systems'],
#       dtype='<U45'), array(['autoregressive', 'data hiding', 'distortion constraints',
#        'distortion measures', 'fundamental capacity limits',
#        'geometric attacks', 'image sources', 'image watermarking',
#        'statistical model', 'wavelet statistical models'], dtype='<U27'), array(['consistent model estimates', 'eiv formulation',
#        'instrumental variables', 'model identification',
#        'moesp algorithm', 'multiple variables', 'order determination',
#        'pca', 'principal component analysis', 'process input',
#        'real industrial process', 'sensor faults', 'simulated process',
#        'subspace identification', 'subspace identification algorithm',
#        'subspace identification approach', 'system matrices',
#        'system observability subspace', 'system order'], dtype='<U33'), array(['full capacity', 'fundamental diagram', 'highway traffic',
#        'lane expansion', 'numerical results', 'phase separation',
#        'phase transition', 'reduced speed', 'saturated flow',
#        'toll collection', 'tollbooth', 'tollbooths', 'traffic flow',
#        'travel time', 'vehicle queuing', 'waiting time'], dtype='<U19'), array(['bagsik oscillator', 'banking data', 'piotrowski',
#        'statistical mechanism apparatus'], dtype='<U31'), array(['adaptive image denoising', 'edge preservation', 'edges',
#        'geometric constraints', 'gradient magnitudes', 'image denoising',
#        'image edges', 'image multiresolution decomposition',
#        'image noise', 'image presegmentation',
#        'redundant wavelet transform', 'scale consistency',
#        'shrinkage function', 'shrinkage functions', 'space consistency',
#        'wavelet coefficients'], dtype='<U35'), array(['compensation', 'distribution network resonant grounding systems',
#        'distribution systems', 'fault detection', 'resfal'], dtype='<U47'), array(['biological ageing', 'cellular automata model', 'movable wolves',
#        'neighbours', 'penna model', 'planar lattice', 'predation',
#        'restraining factor', 'sheep', 'verhulst factor', 'wolves'],
#       dtype='<U23'), array(['adaptive filters', 'approximation images', 'computer generated',
#        'double thresholding technique', 'dynamic range compression',
#        'edge connectivity', 'edge detection', 'edge distortion',
#        'final edge probability image', 'geometrical characteristics',
#        'image', 'image noise', 'matched filters', 'noisy images',
#        'pixel similarity', 'probabilistic formulation',
#        'probability factor', 'reduction', 'spatial domain filtering',
#        'spatially adaptive', 'spatially adaptive wavelet noise',
#        'two wavelet based noise suppression algorithms',
#        'wavelet correlation'], dtype='<U46'), array(['deriveassist', 'deriving model', 'electric generator',
#        'field test measurements', 'generator control simulation',
#        'identification', 'parameter matching', 'power system simulation'],
#       dtype='<U28'), array(['boltzmann equation', 'chain rules', 'continuity',
#        'dispersion model', 'dynamic evolution', 'motorcyclists',
#        'multiclass', 'multilane domain', 'multilane traffic model',
#        'multiplying', 'nonlinear poisson equation',
#        'traffic dispersion model', 'traffic flow', 'variance equation',
#        'vehicular boltzmann equation'], dtype='<U28'), array(['3d haptic', 'cylinder', 'deformable surface',
#        'deformable surfaces', 'interactive 3d volume segmentation',
#        'interactive segmentation', 'medical 3d volume data',
#        'sensory feedback', 'tubular structure'], dtype='<U34'), array(['basis functions', 'coherent layers', 'image compression',
#        'image representation', 'image understanding', 'local transients',
#        'multilayered decomposition algorithm',
#        'multilayered image representation', 'multilayered representation',
#        'oscillatory patterns', 'piecewise smooth regions layer',
#        'residual part', 'sparse representation', 'textures layer',
#        'video coding'], dtype='<U36'), array(['adaptive fuzzy control', 'adaptive fuzzy control procedure',
#        'carbonate fuel cells', 'fuzzy control system', 'fuzzy system',
#        'mcfc', 'mcfc stack', 'neural networks identification',
#        'neural networks model', 'nonlinear modeling',
#        'operating temperature',
#        'radial basis function neural networks identification'],
#       dtype='<U52'), array(['adjacent cell vacancy', 'arching signatures', 'average exit',
#        'cellular automata', 'confined pedestrians',
#        'counterintuitive result', 'diffusive behavior', 'exit dynamics',
#        'iteration time', 'pedestrians', 'relaxed pedestrians', 'sizes',
#        'throughput'], dtype='<U23'), array(['brazilian stock telebras', 'high uncertainties', 'index',
#        'invariant measures', 'poincare',
#        'simultaneously dynamical properties', 'statistical observations',
#        'statistical quantities', 'stock market', 'stock market dynamics'],
#       dtype='<U35'), array(['antipersistent markov behavior', 'foreign exchange markets',
#        'statistical forecast'], dtype='<U30'), array(['-', 'causality constraint', 'digital control systems',
#        'generalized predictive control', 'gpc algorithm', 'lifted models',
#        'non - uniform updating', 'non - uniformly sampled systems',
#        'optimal causal control laws'], dtype='<U31'), array(['decoherence', 'design constraint',
#        'dominant decoherence processes', 'encoding', 'logical qubit',
#        'pulse sequences', 'qubits', 'scalable quantum computing devices',
#        'severe engineering constraints'], dtype='<U34'), array(['coherent field', 'nonclassical feature', 'phase control',
#        'quadrature components', 'quantum field', 'quantum fluctuations',
#        'relative phase'], dtype='<U21'), array(['asymptotic distribution theory', 'asymptotic properties',
#        'asymptotic values', 'confidence intervals', 'detrended',
#        'financial economics', 'finite sample properties',
#        'fluctuation analysis', 'gaussian white noise', 'heuristic',
#        'periodogram regression method', 'periodogram regression methods',
#        'simulated series'], dtype='<U30'), array(['artificial neural network', 'background odorants',
#        'computational capacity', 'computational properties',
#        'continuous curves', 'critical capacity',
#        'critical capacity alpha', 'linear separability',
#        'odorant concentrations', 'odorant discriminator', 'olfaction',
#        'olfactory bulb',
#        'probabilistic receptor affinity distribution model',
#        'quantitative analysis', 'sensory neurons',
#        'single processing linear threshold element'], dtype='<U50'), array(['lukewarm', 'wavelength services'], dtype='<U19'), array(['ghost field', 'marketing', 'mass media', 'percolation theory',
#        'percolative phase transition', 'quality expectations',
#        'social percolation', 'stationary state'], dtype='<U28'), array(['economics', 'quantum game theory', 'quantum market games'],
#       dtype='<U20'), array(['communications infrastructure', 'information control facilities',
#        'information network', 'information network structuring',
#        'information transmission network', 'optical fiber network',
#        'sewage conduits', 'sewer conduits', 'sewer optical fiber teleway',
#        'sewerage'], dtype='<U32'), array(['compensator', 'control error', 'control signal',
#        'friction compensator', 'industrial controllers',
#        'pneumatic control', 'pneumatic control valves', 'static friction'],
#       dtype='<U24'), array(['adaptative distance map', 'cielab1976 color space',
#        'color images', 'complex images', 'global value',
#        'image rendering', 'llab color space', 'local distance map',
#        'objective image quality metric', 'perceptual color differences',
#        'perceptually based metrics', 'pixel by pixel metric',
#        'quality image metrics', 'recursive', 'synthetic',
#        'synthetic images', 'third'], dtype='<U30'), array(['alternating projections', 'blue colors', 'color artifacts',
#        'color filter', 'color plane interpolation', 'color sample',
#        'demosaicing', 'demosaicing technique', 'error', 'mean',
#        'plane interpolation'], dtype='<U25'), array(['auditory information processing',
#        'constant quiescent firing rate', 'hair cell',
#        'information processing performance', 'information theory',
#        'mammalian auditory system', 'peripheral auditory system',
#        'probability measures', 'spiral ganglion neuron',
#        'synaptic depression', 'weak sinusoidal signals'], dtype='<U34'), array(['exact controllability', 'fourier method', 'minimal time',
#        'shells', 'thin cups'], dtype='<U21'), array(['coding properties', 'lateral inhibition',
#        'lateral inhibition enhances', 'neural network',
#        'neural network architecture', 'neural network architectures',
#        'neuroanatomical', 'neuropsychological data',
#        'perceptual representations', 'postintegration lateral inhibition',
#        'preintegration', 'unsupervised learning'], dtype='<U34'), array(['balance', 'bonds', 'levy distributions', 'natural martingale',
#        'non - gaussian fluctuations', 'non - gaussian price fluctuations',
#        'option pricing', 'path integral', 'path integral formalism',
#        'stochastic calculus', 'stocks', 'truncated',
#        'truncated levy distributions'], dtype='<U33'), array(['algorithm performance', 'chromaticity', 'clipping',
#        'color constancy', 'color constancy quantities',
#        'computational color constancy',
#        'computational color constancy algorithms', 'correlation method',
#        'finlayson', 'gray world methods', 'ground truth',
#        'illumination invariant', 'limiting case', 'reflectance spectra',
#        'retinex method', 'scene illuminant', 'synthesized data'],
#       dtype='<U40'), array(['food service companies', 'internet presence', 'investment',
#        'marketing', 'restaurant web sites', 'web presence',
#        'website design', 'website effectiveness'], dtype='<U22'), array(['british pound', 'canadian dollar', 'currencies',
#        'dynamical behaviours', 'euro',
#        'european monetary system currency exchanges',
#        'foreign currencies', 'japanese yen', 'nonexistence', 'nonlinear',
#        'nonlinear time series analysis techniques', 'recurrence plots',
#        'recurrence quantification analysis', 'stationarity',
#        'time series', 'time series analysis'], dtype='<U43'), array(['bionics', 'cellular automaton model', 'chemotaxis', 'coupling',
#        'couplings', 'evacuation processes', 'herding',
#        'herding behaviour', 'minimal evacuation times',
#        'non - monotonic dependence', 'pedestrian dynamics', 'pedestrians'],
#       dtype='<U26'), array(['power electronics', 'power systems', 'system dynamics',
#        'utilities'], dtype='<U17'), array(['av software', 'internet resources', 'intrusion attempts',
#        'rule sets', 'top notch programmers', 'trojan horses',
#        'virus hunting'], dtype='<U21'), array(['based marketing', 'content analysis', 'descriptive study',
#        'hotel', 'hotel industry', 'hotel web sites', 'marketing',
#        'marketing tool', 'multimedia', 'relationship marketing',
#        'strategic', 'strategic exploitation',
#        'web based relationship marketing', 'web content survey',
#        'web marketing applications', 'web presence', 'web sites',
#        'world wide web marketing'], dtype='<U32'), array(['measurement models', 'observer decomposition',
#        'sparse system models', 'visual aid'], dtype='<U22'), array(['abstract representations', 'abstract rules',
#        'arbitrary input symbols', 'evolutionary psychology',
#        'exemplar presentation', 'generalized abstract structures',
#        'grammatical knowledge', 'internal representations',
#        'learning algorithms', 'linguistic theory',
#        'long term potentiation', 'mammalian nervous system', 'sets',
#        'state variable', 'symbol sets', 'symbolic knowledge',
#        'weight adaptation'], dtype='<U31'), array(['background clutter', 'compensation', 'contour detection',
#        'edge indicator function', 'edge map',
#        'inverted distance transform', 'minimization',
#        'nonparameterized object contours', 'object motion',
#        'spurious edges', 'topographical distance', 'watershed algorithm',
#        'watershed segmentation'], dtype='<U32'), array(['daily realized futures volatility', 'financial practitioners',
#        'futures return series', 'logarithmic standard deviations',
#        'market trend', 'pricing', 'realized volatility',
#        'reliable identification', 'risk management',
#        'singular spectrum analysis', 'ssa', 'toolbox',
#        'underlying market periodicities', 'volatility series'],
#       dtype='<U33'), array(['business managers', 'commercial security standards',
#        'corporate systems', 'formal risk management framework',
#        'management services practitioners', 'managing system risk',
#        'security risks'], dtype='<U33'), array(['chromaticity', 'color constancy',
#        'common illumination conditions',
#        'computational color constancy algorithms', 'correlation',
#        'finlayson', 'gray world methods', 'image',
#        'image chromaticity statistics', 'image data', 'pixel intensity',
#        'preprocessing strategies', 'retinex', 'scene', 'synthesized data'],
#       dtype='<U40'), array(['affine invariants', 'computing complexity', 'convex polygons',
#        'image registration', 'object recognition'], dtype='<U20'), array(['chebyshev metric', 'vector evaluations'], dtype='<U18'), array(['active laser triangulation', 'fragile fused silica crucible',
#        'geometry', 'highly', 'highly irregular shaped objects', 'nugget',
#        'optimal nugget placement', 'packing algorithm',
#        'packing constraints', 'polycrystalline silicon nuggets',
#        'pulling', 'robotic system', 'sampling frequency',
#        'semiconductor manufacturing', 'semiconductor wafer production'],
#       dtype='<U31'), array(['additive images', 'binocular image pair', 'binocular model',
#        'binocular parallax', 'constituent phasors', 'fourier transform',
#        'inverse fourier transform', 'occluding', 'occluding images',
#        'segmentation', 'short baseline binocular image pairs',
#        'spatial shift', 'translucent objects'], dtype='<U36'), array(['image painting', 'incomplete set', 'interactive image editing',
#        'physical 3d scene', 'plenoptic', 'plenoptic image editing',
#        'scene illuminations', 'viewpoints',
#        'volumetric decomposition technique'], dtype='<U34'), array(['classroom edition', 'microsoft powerpoint', 'television'],
#       dtype='<U20'), array(['arbitrarily shaped apertures', 'broad frequency spectra',
#        'circular aperture', 'circular mask', 'circular mask diffraction',
#        'coded imaging systems', 'convolution', 'diffraction limit',
#        'gamma', 'intensity distribution', 'masks', 'multiaperture mask',
#        'optical information processing', 'periodic apertures',
#        'periodic apertures imaging', 'periodic rectangular apertures',
#        'periodic rectangular apertures array', 'pinhole cameras',
#        'single aperture', 'visible light'], dtype='<U36'), array(['simlib'], dtype='<U6'), array(['classical convergent correlator', 'convergent correlator',
#        'deformed fringe patterns',
#        'fourier transform profilometry technique',
#        'logarithmic radial harmonic filter',
#        'mellin radial harmonic decomposition', 'optical recognition',
#        'scale invariance', 'scale invariance property'], dtype='<U40'), array(['craft woodworkers', 'dynamic programming', 'flip',
#        'flip analysis', 'managerial decision making',
#        'solitaire board game'], dtype='<U26'), array(['3d lambertian surface structure', '3d surface reconstruction',
#        'arbitrary unknown object motion',
#        'automatic surface reconstruction', 'fixed camera', 'geotensity',
#        'lighting', 'linear intensity subspaces', 'static camera'],
#       dtype='<U32'), array(['centroid detection', 'centroids', 'modulus', 'moment function',
#        'multiple objects', 'optical correlation', 'optical correlator',
#        'single intensity filter', 'spatial light modulators', 'squaring'],
#       dtype='<U24'), array(['bit', 'bit plane coding strategies', 'bit plane overhead',
#        'block truncation coding',
#        'block truncation image bit plane coding', 'compression ratio',
#        'discrete cosine transform', 'image compression', 'overheads',
#        'plane overhead', 'vector quantization',
#        'wavelet transform coding'], dtype='<U39'), array(['addition operation', 'carry propagation', 'digits',
#        'incoherent correlator', 'minterms', 'operand length',
#        'optoelectronic shared', 'reference digits', 'shared content',
#        'symbolic substitution', 'system complexity'], dtype='<U21'), array(['dynamic magnetic resonance', 'dynamic mr signal',
#        'image material', 'images', 'inherent scale selection selection',
#        'location accuracy', 'morphological scale spaces',
#        'neural net classifier', 'noise level', 'optimal sampling',
#        'overall error rate', 'paramagnetic tracer', 'spatial features',
#        'spatial properties'], dtype='<U34'), array(['3d correlation', '3d fourier transform', '3d functions',
#        '3d signals', 'color distribution', 'color images',
#        'color pattern recognition tasks', 'optical correlator',
#        'optical encoding'], dtype='<U31'), array(['active vision systems', 'calibration', 'calibration parameters',
#        'camera calibration parameters', 'discrete motion',
#        'flow measurements', 'geometric analysis', 'geometry',
#        'image derivatives', 'image motion', 'optical flow',
#        'point correspondences', 'projective transformation',
#        'rigidly moving camera', 'rotational component',
#        'rotational components', 'video databases'], dtype='<U29'), array(['geometrical optics', 'go 3d', 'go 3d program', 'image tree',
#        'indoor propagation', 'input file', 'long corridor', 'preset',
#        'receiver locations', 'reflections'], dtype='<U18'), array(['application algorithms', 'jets', 'message passing',
#        'multiprocessor systems', 'numerical solution'], dtype='<U22'), array(['local alignment', 'panoramic image mosaics'], dtype='<U23'), array(['accurate scene analysis', 'cast shadow',
#        'combined probability map', 'convex hull', 'edge map',
#        'effective moving cast shadow detection',
#        'erroneous scene analysis', 'error rate', 'gradient density',
#        'lighting conditions', 'monocular color traffic image sequences',
#        'moving cast shadow', 'robust segmentation',
#        'selected vehicle edge pixels', 'shadow confidence score',
#        'vehicle images', 'vehicle segmentation', 'vehicle sizes'],
#       dtype='<U39'), array(['3d anatomical models', 'anatomical scenes',
#        'building 3d anatomical scenes', 'planar oblique slices'],
#       dtype='<U29'), array(['compressible', 'inverse problems', 'ion exchange',
#        'ion exchanger', 'mathematical model', 'unique solvability'],
#       dtype='<U18'), array(['adverse effects', 'blazed phase grating', 'broadband imagery',
#        'broadband imaging system', 'chromatic aberrations', 'diffraction',
#        'digital image restoration technique', 'dispersion', 'gimbals',
#        'incident wavelengths', 'lcopa', 'mirrors',
#        'nematic liquid crystal optical phased array',
#        'nonmechanical device', 'phase grating', 'postprocessing',
#        'reflectivities', 'spectral', 'wiener deconvolution filter'],
#       dtype='<U43'), array(['computational procedures', 'computer processing', 'concussion',
#        'mental impairments', 'patients'], dtype='<U24'), array(['2d vhf images', '3d polygonal representation',
#        'biological soft tissues', 'biomechanical research',
#        'detailed finite element model', 'human kidney',
#        'hyperelastic material model', 'image segmentation', 'kidney',
#        'national library', 'organ reconstruction software',
#        'polygonal surfaces', 'robust 3d hexahedral finite element',
#        'trauma research'], dtype='<U35'), array(['evpi', 'maximum evpi', 'partial information', 'probabilities',
#        'probability distribution'], dtype='<U24'), array(['approval voting', 'borda count', 'choice', 'election outcome',
#        'plurality voting', 'presidential campaign', 'united states'],
#       dtype='<U21'), array(['adaptive filtering', 'adaptive filtering method',
#        'adaptive spatial filtering method', 'color gradients',
#        'color image processing', 'edge detection', 'generated edge maps',
#        'hsi color model', 'hue', 'hue saturation intensity',
#        'hue saturation intensity color space', 'image analysis',
#        'minimum error rate', 'noise characteristics', 'noise reduction',
#        'noise variance', 'nonuniform noise distribution',
#        'random gaussian noise', 'rgb color model', 'rgb image',
#        'saturation'], dtype='<U36'), array(['maps', 'numerical simulation', 'phase inconsistency',
#        'phase unwrapping algorithm', 'postprocessor', 'stability',
#        'time effective phase unwrapping', 'unwrapping',
#        'unwrapping problem', 'wrapped map'], dtype='<U31'), array(['camera calibration', 'camera parameters',
#        'computer vision inspection', 'fully automatic algorithm',
#        'fully automatic camera calibration',
#        'intelligent roi location algorithm', 'radon transform',
#        'region of interest', 'region of interest location', 'zoom lens'],
#       dtype='<U34'), array(['bayes formula', 'bayesian formulation',
#        'conditional probability distributions', 'maximizing entropy',
#        'maximum entropy', 'optimal threshold determination',
#        'parabola concave', 'parabola convex', 'searching algorithm'],
#       dtype='<U37'), array(['critical path', 'spreadsheet', 'spreadsheet environment'],
#       dtype='<U23'), array(['engineering', 'error experimentation', 'graduate education',
#        'management', 'preparation'], dtype='<U21'), array(['bayesian method', 'linear regression parameters',
#        'linear regression problems', 'pseudoinverse method',
#        'pseudoinversion', 'regularization method',
#        'regularizing algorithms', 'robust estimation'], dtype='<U28'), array(['denoising algorithm', 'modified averaging operation',
#        'noise pattern', 'noise sensitivity', 'positioning accuracy',
#        'randomness', 'superresolved position estimation',
#        'tracking systems'], dtype='<U33'), array(['compressibility', 'cylindrical plasma source',
#        'electromagnetic hybrid model', 'field reversal layer',
#        'finite size', 'helmholtz instability', 'hybrid simulation',
#        'magnetic field', 'magnetized plasma flow',
#        'magnetopause shear layer', 'massless fluid', 'particle mixing',
#        'pressure anisotropy', 'shear region', 'space plasmas',
#        'tangential discontinuity', 'transition layer'], dtype='<U28'), array(['acquisition noise', 'cielab', 'liquid crystal tunable filter',
#        'monochrome ccd camera', 'multispectral color image acquisition',
#        'multispectral color image capture',
#        'principal eigenvector approach', 'spectral model',
#        'spectral reflectance', 'spectral transmittance', 'tunable filter'],
#       dtype='<U37'), array(['colours', 'convolutions', 'curvature computation',
#        'curvature scale space method', 'curvatures', 'gaussian curvature',
#        'geodesic', 'geodesic line', 'in', 'local', 'mean curvature',
#        'mean curvature values', 'parametrisations', 'properties',
#        'semigeodesic coordinates', 'smoothed surface curvatures',
#        'smoothing', 'surface', 'surface noise', 'volumetric diffusion'],
#       dtype='<U28'), array(['orthoscopic', 'orthoscopic real images', 'viewing resolution'],
#       dtype='<U23'), array(['computed tomography', 'ct images', 'diagnostic',
#        'image interpretation', 'lung metastasis detection', 'nodules',
#        'thorax', 'thorax contour', 'tumors'], dtype='<U25'), array(['kurtosis', 'noise distribution', 'smoothing functional',
#        'smoothing functionals'], dtype='<U21'), array(['convenience', 'data processing', 'detected hologram',
#        'digital holography', 'discrete fresnel integral', 'image quality',
#        'laplacian', 'numerical reconstruction', 'reconstructed image'],
#       dtype='<U25'), array(['algorithm moire interferometry', 'digital differentiation',
#        'displacement field', 'gabor filters', 'moire pattern',
#        'multichannel gabor filter', 'strain contouring',
#        'strain segmentation'], dtype='<U30'), array(['autofocusing', 'automatic focus', 'dc motor', 'defocused signal',
#        'differential amplification', 'eccentric light beam',
#        'electric signal', 'high resolution', 'microprocessor',
#        'microscope autofocusing', 'object lens',
#        'reflected light position', 'semiconductor laser device',
#        'symmetrical silicon photocell', 'wide focusing range'],
#       dtype='<U29'), array(['hierarchical structure', 'inverse problem', 'parabolic equation'],
#       dtype='<U22'), array(['arbitrary cuts', 'cutting', 'disconnected mesh structure',
#        'generalized cutting scheme',
#        'generalized interactive mesh cutting', 'interactive mesh cutting',
#        'layered surface', 'loop cautery tool', 'scissors',
#        'surgical simulation', 'tetrahedral objects', 'virtual object',
#        'virtual scalpel', 'virtual tools'], dtype='<U36'), array(['abstract geometrical model', 'bony structures',
#        'computed tomography scans', 'computer monitor', 'documentation',
#        'endoscopic', 'fluoroscopic images', 'image modalities',
#        'intra operatively generated images', 'medical image',
#        'medical image modalities', 'medical images', 'operation planning',
#        'orthopaedic surgery', 'orthopaedic surgical navigation',
#        'orthopaedics', 'preoperative image data', 'surgical action',
#        'surgical education', 'surgical instruments',
#        'surgical navigation systems'], dtype='<U34'), array(['adaptive digital watermarking',
#        'adaptive digital watermarking scheme', 'copyright protection',
#        'digital watermarking', 'fuzzy logic technique',
#        'fuzzy logic techniques', 'human visual system model',
#        'imperceptible watermark'], dtype='<U36'), array(['algorithmic complexity', 'arithmetic operations',
#        'arithmetic processors', 'computational electromagnetics',
#        'computational electromagnetics codes', 'computer architecture',
#        'computer hardware', 'dense matrices', 'fdtd loops',
#        'lu factorizations', 'reference platforms'], dtype='<U36'), array(['dynamic motion analysis', 'dynamic programming',
#        'heuristic modification', 'matching optimization problem',
#        'modified dynamic programming', 'motion estimation',
#        'motion vector', 'multiple dynamic images'], dtype='<U29'), array(['bayesian decision procedure', 'minimal probability content',
#        'partial prior information', 'statistical inference'], dtype='<U27'), array(['boundedly rational firms', 'demographic groups',
#        'endogenously evolving institution', 'french labor market',
#        'hiring standards', 'internal labor markets', 'labor market',
#        'mobility patterns', 'oil crisis'], dtype='<U33'), array(['bayesian probability revision', 'management sciences',
#        'monetary decisions', 'operations research',
#        'sequential decision analysis', 'single decision analysis',
#        'stochastic dynamic programming', 'utility theory'], dtype='<U30'), array(['bar code labels', 'farmland foods', 'food processing',
#        'wireless terminals'], dtype='<U18'), array(['bilingual material', 'bilingual web designs',
#        'bilingual web sites', 'information architecture'], dtype='<U24'), array(['business environment', 'large scale', 'linear constraints',
#        'linear inequalities', 'linear programming',
#        'mathematical programming', 'mixed programming', 'modelling',
#        'operations research'], dtype='<U24'), array(['clock signal', 'continuous wave light',
#        'semiconductor optical amplifiers'], dtype='<U32'), array(['academic libraries', 'academic science librarians',
#        'gift acceptance', 'gift processing', 'investment',
#        'library budget', 'library collections', 'professional decisions',
#        'proposed collections', 'science academic librarian gifts',
#        'universities'], dtype='<U32'), array(['dubious quality', 'internet', 'online advice', 'personalization',
#        'predictability', 'trust', 'web design'], dtype='<U15'), array(['academic library', 'special collections'], dtype='<U19'), array(['alternative routeing dynamics', 'average', 'average delay',
#        'average machine utilization', 'changing part mix ratios',
#        'combined dispatching', 'dispatching rules',
#        'finite buffer capacity', 'flexible manufacturing system',
#        'flow time', 'local input buffers', 'part mix ratios',
#        'performance measures', 'routeing', 'routeing strategies',
#        'simulation'], dtype='<U29'), array(['decision models', 'decision support systems', 'ms education',
#        'ms educators', 'primary delivery vehicle',
#        'quantitative modeling techniques', 'spreadsheets',
#        'teaching management science'], dtype='<U32'), array(['industry', 'life cycle', 'model', 'personal computer industry',
#        'price', 'process innovations', 'quality'], dtype='<U26'), array(['academic programs', 'beachhead', 'communal infrastructure',
#        'ia journal', 'information architecture',
#        'local professional groups'], dtype='<U25'), array(['discrete output feedback sliding mode control',
#        'extraneous disturbances', 'low sensitivity',
#        'moving switching line technique', 'output sampling feedback',
#        'reaching law approach', 'second order systems', 'sliding motion',
#        'switching', 'switching line', 'switching variable',
#        'system states'], dtype='<U45'), array(['assembly module', 'computer aided design',
#        'cost estimation module', 'design feasibility technique',
#        'initial process planning', 'innovative product development',
#        'material selection module', 'moulding processes',
#        'process optimization module', 'product cost',
#        'product cost modelling', 'to', 'user interface'], dtype='<U30'), array(['aluminium alloy', 'cutting speed', 'fractal dimension',
#        'fractals', 'frictional boundary conditions', 'geometry',
#        'machining', 'non - euclidean contact geometry', 'tool rake face'],
#       dtype='<U32'), array(['body forces', 'boundary value problems', 'darcy law', 'effect',
#        'equations', 'moulding', 'non - newtonian flows',
#        'nonlinear systems', 'nonlinearity', 'pressure gradient',
#        'weak solutions'], dtype='<U23'), array(['bounded rationality', 'cognitive constraints',
#        'emotional arousal', 'high emotional arousal', 'rational thinking'],
#       dtype='<U22'), array(['library collections', 'literature', 'underground poetry'],
#       dtype='<U19'), array(['advertising campaign', 'linear constraints', 'mathematical model',
#        'nonlinear programming', 'operations research problems'],
#       dtype='<U28'), array(['decision analysis', 'management science', 'mba',
#        'numeracy skills', 'optimization', 'simulation',
#        'sophisticated management science'], dtype='<U32'), array(['computer articulating', 'information architecture',
#        'information interaction', 'information interactivity',
#        'navigational aid'], dtype='<U25'), array(['collection development', 'history', 'medicine', 'science'],
#       dtype='<U22'), array(['covariance matrix', 'crop production component',
#        'crop production modeling', 'dekadly rainfall', 'dekads',
#        'estimated rainfall parameters', 'food system', 'groundnuts',
#        'long time series', 'maize', 'meteorological records',
#        'meteorological stations', 'multivariate normal distribution',
#        'pronounced spatial correlation', 'random numbers',
#        'simulation model', 'small grains', 'southern africa',
#        'spatial correlation', 'spatial rainfall simulator',
#        'standard deviation', 'temporal correlation', 'units', 'zimbabwe'],
#       dtype='<U32'), array(['amplitude oscillations', 'asymptotically unbounded solutions',
#        'attracting', 'canard explosion', 'enzymatic reactions',
#        'enzyme activities', 'global bifurcation', 'global stability',
#        'limit cycles', 'metabolite concentration', 'nonlinear dependency',
#        'nonnegative data', 'ordinary differential equations', 'rate',
#        'saturation kinetics', 'set'], dtype='<U34'), array(['additive', 'cantilever', 'ceiling', 'deflection analysis',
#        'integrated additive', 'large castle model',
#        'layered manufacturing process', 'machining',
#        'material removal process',
#        'numerical control machining configurations', 'overhang',
#        'stacking operations', 'stock layers',
#        'subtractive shaping theories', 'subtractive shaping theory',
#        'support structure design', 'vaulted overhang'], dtype='<U42'), array(['boundary element design', 'boundary element method',
#        'boundary integral sensitivity formulations',
#        'cavity temperature distributions', 'design sensitivity analysis',
#        'injection moulding', 'injection moulds', 'iterative algorithm',
#        'objective function'], dtype='<U42'), array(['circular structures', 'collective choice procedures',
#        'hierarchical organization', 'structures',
#        'ultimate control group', 'voting'], dtype='<U28'), array(['market demand', 'materials requirements planning',
#        'materials requirements planning performance', 'peak demand',
#        'replenishment order triggering', 'safety stocks',
#        'stock positioning', 'strategic stocks', 'target service level'],
#       dtype='<U43'), array(['centrifugal loads', 'concurrent engineering',
#        'finite element analysis', 'fixed guide vanes',
#        'fused decomposition modelling', 'impulse turbine blades',
#        'rapid prototyping', 'university of limerick',
#        'wave energy power conversion', 'wave energy research team'],
#       dtype='<U29'), array(['counterpropagating feedback configuration', 'gain',
#        'mutual gain modulation', 'nonlinearity'], dtype='<U41'), array(['@ risk', 'academic exercise', 'blitzograms',
#        'monte carlo simulation packages', 'probability distributions'],
#       dtype='<U31'), array(['circuit analysis', 'computer network',
#        'flow spanning tree enumeration', 'minimal paths', 'node pair',
#        'requirements', 'spanning tree', 'spanning trees',
#        'structural mps', 'undirected graphs'], dtype='<U30'), array(['discounted utility model', 'health outcomes',
#        'hyperbolic discounting models', 'hyperbolic models',
#        'intertemporal preferences', 'models', 'monetary outcomes',
#        'preferences', 'stationarity axiom'], dtype='<U29'), array(['copnet', 'cumbersome navigation', 'database systems',
#        'enforcement', 'graphical user interface',
#        'information architecture', 'law enforcement agency',
#        'law enforcement users', 'nonexperts', 'personnel', 'reasons',
#        'rms experts', 'switching', 'system design', 'usability'],
#       dtype='<U24'), array(['decision rights', 'modular design', 'modularity',
#        'property rights', 'residual claims'], dtype='<U15'), array(['flexible manufacturing system', 'fms', 'fuzzy logic approach',
#        'intelligent fuzzy decision support system',
#        'intelligent fuzzy decision system', 'manufacturing system',
#        'performance measures', 'routing', 'scheduling fmss',
#        'simulation model'], dtype='<U41'), array(['bounded rationality', 'dodson law', 'emotional arousal'],
#       dtype='<U19'), array(['138 kv', 'alaska', 'battery energy storage system'], dtype='<U29'), array(['civic activities', 'economic development', 'ecosystems',
#        'information architects',
#        'networked electronic environment design',
#        'networked environments', 'urban internet', 'web sites'],
#       dtype='<U39'), array(['autograph', 'dust jacket', 'edition', 'fair market value', 'fot'],
#       dtype='<U17'), array(['collections materials', 'james ford bell library'], dtype='<U23'), array(['business school management', 'business school management science',
#        'decision makers', 'management', 'management science',
#        'management science tools', 'mba programs', 'professional',
#        'student mathematical preparation'], dtype='<U34'), array(['aliasing', 'am images', 'attenuation map', 'computer simulations',
#        'ct detector model', 'ct detector response',
#        'foreign metal bodies', 'measurement noise', 'metal artifacts',
#        'metal foreign objects',
#        'patients bearing metal intracavitary applicators',
#        'polyenergetic spectra', 'polyenergetic spectrum',
#        'quantitative computed tomography imaging', 'scattered radiation',
#        'severe artifacts', 'signal acquisition', 'simplified model',
#        'statistical image reconstruction', 'streaking artifacts',
#        'tissue attenuation coefficients'], dtype='<U48'), array(['anatomical information', 'automatic registration method',
#        'automatic ridged body transformations', 'ct scans', 'datasets',
#        'full circle', 'head and neck', 'head and neck area',
#        'image fusion methods', 'match results', 'pet scan',
#        'positron emission tomography', 'radiotherapy treatment mask',
#        'registration technique', 'reproducible positioning', 'test',
#        'transmission', 'tumor biology', 'voxel size'], dtype='<U37'), array(['autograph', 'condition', 'dust jacket'], dtype='<U11'), array(['emotion', 'emotional choice systems', 'emotional systems',
#        'expectations', 'higher level deliberation'], dtype='<U25'), array(['arbitrary permutation', 'blocks', 'conflictless realization',
#        'hypercube', 'hypercubes', 'multiring', 'multirings',
#        'nonlockability', 'transmission'], dtype='<U24'), array(['coordinate axes', 'coordinate planes', 'linear discrete systems',
#        'multidimensional stability', 'stable polynomials'], dtype='<U26'), array(['asymptotic probabilistic stability', 'markov process',
#        'nonlinear systems', 'perturbed', 'phase trajectory',
#        'phase vector', 'probabilistic stability', 'random jump',
#        'random jumps', 'stability', 'stochastic systems'], dtype='<U34'), array(['computational clusters', 'dynamic characteristics',
#        'dynamic control', 'metacomputational media', 'scalable resources',
#        'software applications', 'static scaling'], dtype='<U23'), array(['auditory', 'electronic devices', 'fuzzy linear regression',
#        'fuzzy set theory', 'human thought', 'information systems',
# ...
#        'program', 'programming schema', 'sequential prolog processes'],
#       dtype='<U40'), array(['feedback interconnection', 'genetic',
#        'multiobjective genetic algorithms', 'multiobjective optimization',
#        'multiobjective problem', 'multiobjective robust control design'],
#       dtype='<U36'), array(['abnormal behavior', 'fault components',
#        'fault detection mechanism', 'fault diagnosis',
#        'floating disc experimental setup', 'floating disc system',
#        'genetic algorithms', 'mechatronic systems',
#        'predicted system behavior', 'qbg', 'qualitative bond graph',
#        'qualitative bond graphs', 'qualitative equations',
#        'unified approach'], dtype='<U32'), array(['autotuning', 'barrel temperature', 'model predictive control',
#        'multiple parameter pid', 'temperature control'], dtype='<U24'), array(['chountasis', 'continuous variables', 'gaussian noise',
#        'quantum communication', 'quantum communication theory',
#        'quantum information processing systems',
#        'quantum mechanical systems', 'quantum teleportation'],
#       dtype='<U38'), array(['private sector', 'sis', 'strategic information systems',
#        'strategic operations', 'sustainable competitive advantage'],
#       dtype='<U33'), array(['database systems', 'disk accesses', 'indexes', 'overhead',
#        'performance', 'performance evaluation', 'relocation process',
#        'simulation', 'unavoidable preprocessing step'], dtype='<U30'), array(['adaptive beamforming', 'adaptively separating',
#        'broadband sources', 'electromagnetic vector sensor',
#        'parallel spatial processors', 'preprocessings', 'snr',
#        'source trackers', 'tracking', 'uncorrelated sources'],
#       dtype='<U29'), array(['geographic considerations', 'internet domain name',
#        'trademark dispute', 'trademark law'], dtype='<U25'), array(['classmates', 'electronic telecommunications', 'fostering',
#        'instruction', 'instructor', 'interpersonal relationships',
#        'student attitudes', 'students', 'supplementary aid', 'teachers'],
#       dtype='<U29'), array(['arbitrary thickness', 'coaxial', 'coaxial couplers',
#        'coaxial waveguides', 'complex cross section',
#        'computational cost', 'conformal mapping', 'degrees of freedom',
#        'external shields', 'metallic diaphragms',
#        'nonsymmetrical couplers', 'numerical',
#        'polygonal inner conductors', 'symmetrical coaxial couplers'],
#       dtype='<U28'), array(['activation time map', 'catheter laboratory',
#        'clinical conditions', 'clinical ecg mapping', 'ecg mapping data',
#        'gauss', 'heart', 'individual optimal regularization',
#        'inverse algorithm',
#        'noninvasive myocardial activation time imaging',
#        'nonlinear problem formulation', 'regularized linear problems',
#        'simulated', 'single beat', 'sinus rhythm data'], dtype='<U46'), array(['auxiliary circuitry', 'cmos technology',
#        'direct digital modulation', 'supply voltage'], dtype='<U25'), array(['abdominal movement recordings', 'adult respiratory volume',
#        'artificial neural networks', 'automated breath detection',
#        'backpropagation', 'breath detection', 'classification',
#        'difference', 'expiration onsets', 'feedforward',
#        'full night continuous recordings', 'human expert',
#        'human expert results', 'infant sleep data', 'inspiration',
#        'postprocessing', 'respiratory data', 'respiratory volume signal',
#        'uncalibrated rib cage'], dtype='<U32'), array(['circuit performance', 'complete circuit performance',
#        'complete detector', 'convolution', 'external circuit', 'gaas',
#        'millimeter waves', 'mixer circuit', 'msms',
#        'optical responsivity', 'photomixer', 'response speed',
#        'strong interdependence'], dtype='<U28'), array(['amf', 'censored fast maximum likelihood', 'computer simulations',
#        'covariance matrix', 'covariance matrix estimate', 'fml',
#        'fml algorithms', 'maximum likelihood estimation', 'mle solution',
#        'outlier', 'outlier data vectors',
#        'outlier resistant adaptive matched filtering', 'outliers',
#        'reiterative', 'robust adaptive matched filtering',
#        'sample matrix inversion', 'steering vector',
#        'stressful outlier scenarios', 'vectors'], dtype='<U44'), array(['asymptotic waveform evaluation', 'differential',
#        'differential equations', 'differential quadrature method',
#        'disparate', 'dqm', 'dqm approximation', 'equations',
#        'global sampling', 'interconnects',
#        'lossy nonuniform transmission lines', 'model lossy',
#        'multiport models', 'numerical approximation',
#        'pade approximation', 'port voltages', 'quadrature methods',
#        'rational', 'spice', 'transcendental functions',
#        'transmission lines', 'weighted linear sum'], dtype='<U35'), array(['benchmark', 'closed loop conditions', 'controller performance',
#        'controller performance analysis', 'data driven subspace approach',
#        'deterministic inputs', 'explicit parametric model',
#        'external excitations', 'feedforward control',
#        'linear quadratic gaussian', 'lqg', 'lqg tradeoff curve',
#        'multivariate systems', 'output variances', 'profit analysis',
#        'setpoint excitation', 'stochastic inputs', 'univariate'],
#       dtype='<U31'), array(['command feedforward',
#        'disturbance cancellation robust controller',
#        'feedback controller', 'fuzzy adapted inverse model',
#        'fuzzy control scheme', 'inverse model', 'inverse plant model',
#        'nominal case', 'nonlinear dynamic behavior',
#        'operating conditions', 'reference model',
#        'regulation control performances',
#        'regulation control requirements', 'robust speed control',
#        'speed control scheme', 'speed dynamic response',
#        'switched reluctance motor', 'tracking', 'tracking response'],
#       dtype='<U42'), array(['bitline sensing', 'die efficiency', 'dissipation',
#        'low supply voltage', 'memory cell', 'sense amplifiers'],
#       dtype='<U18'), array(['compilers', 'emit namespace', 'executable code',
#        'net common language', 'regex class', 'regular expressions',
#        'regularexpressions namespace', 'sdk', 'source code', 'time'],
#       dtype='<U28'), array(['achievement', 'instructional web materials', 'learning',
#        'presentation elements', 'table borders', 'treatment',
#        'vertical spacing', 'white space'], dtype='<U27'), array(['airgate pcs', 'charter communications', 'cheap company stock',
#        'confidence from', 'cox communications',
#        'crown castle international', 'industry insiders',
#        'insider buying', 'insider investment', 'national economy',
#        'nextel communications', 'nortel networks', 'telecom industry'],
#       dtype='<U26'), array(['functional obfuscator', 'obfuscation', 'obfuscator',
#        'obfuscators', 'renaming', 'reverse engineering'], dtype='<U21'), array(['instrument symbols', 'interconnection', 'isa', 'isa dictionary',
#        'pid standard', 'process equipment', 'process industry'],
#       dtype='<U18'), array(['accounts', 'multiple', 'remote desktop', 'remote machine',
#        'terminal server', 'terminal services', 'user switching',
#        'windows xp'], dtype='<U17'), array(['arrythmias', 'cluster analysis', 'computational complexity',
#        'distortion measure', 'distortion measures', 'drug effects',
#        'ecg analysis', 'ecg cycles', 'late potential analysis',
#        'nonsmooth optimization problem',
#        'perturbation stochastic approximation', 'price',
#        'randomization procedure', 'spsa', 'vector quantization',
#        'ventricular activation', 'widely'], dtype='<U37'), array(['blended estimate', 'calspan', 'correctness',
#        'effectiveness estimation', 'failure effectiveness',
#        'filter spawning', 'mmae bank',
#        'multiple model adaptive estimation', 'partial actuator',
#        'partial actuator failures', 'partial failure adaptation',
#        'partial failures', 'probability', 'spawned filters',
#        'truth model'], dtype='<U34'), array(['fuzzy event detector', 'fuzzy events detection', 'hybrid systems',
#        'hybrid systems theory', 'linguistic model',
#        'oxichlorination reactor', 'process events', 'supervisory control',
#        'supervisory control design', 'supervisory control scheme',
#        'vinyl monomer plant'], dtype='<U26'), array(['business activities', 'commercial laws', 'consumer interests',
#        'internet activity', 'internet treaties', 'legal jurisdiction',
#        'libel', 'online activities', 'overseas lawsuits', 'treaties',
#        'virtual borders'], dtype='<U19'), array(['cellular automaton', 'computer simulation',
#        'human intestinal microflora', 'model intestinal microflora',
#        'molecular methods'], dtype='<U27'), array(['adjusted hotelling', 'bayes', 'electroencephalogram',
#        'electromagnetic source analysis', 'magnetoencephalogram',
#        'model selection', 'msp residual variance', 'noise settings',
#        'source amplitudes', 'wald test'], dtype='<U31'), array(['damping effects', 'dc transfer function', 'lossy spice models',
#        'ohmic losses', 'switch waveforms analysis'], dtype='<U25'), array(['artificial intelligence', 'autonomous behavior',
#        'autonomous system', 'biological hints', 'biological model',
#        'biological modeling', 'computational model', 'cortical framework',
#        'endowing', 'intelligent behavior', 'internal drives',
#        'learning rules', 'system'], dtype='<U23'), array(['genetic', 'genetic algorithm', 'performance assessment',
#        'performance assessment rules', 'process dynamics',
#        'tuning formula', 'tuning method'], dtype='<U28'), array(['ground speed changes', 'horizontal waypoint guidance',
#        'horizontal waypoint guidance design',
#        'linear quadratic regulator', 'lyapunov stability theorem',
#        'optimal control', 'optimal waypoint changing points',
#        'stability bound', 'waypoint line segments'], dtype='<U35'), array(['cardiac interference', 'fetal biomagnetic recordings',
#        'fetal cardiac complexes', 'maternal cardiac interference',
#        'modified matched filter', 'signal processing',
#        'signal space projection', 'spatial filtering'], dtype='<U29'), array(['active microwave circuits', 'active nonlinear microwave circuits',
#        'anisotropic pml absorbing material', 'benchmark test',
#        'computation time', 'electromagnetic analysis',
#        'extended fetd algorithm', 'fetd lattices', 'global',
#        'matched layers', 'mesh flexibility', 'microstrip line',
#        'microwave amplifier', 'nyquist sampling criterion',
#        'perfectly matched layers', 'propagation bandwidth',
#        'simulation accuracy', 'spatial discretization', 'truncation'],
#       dtype='<U35'), array(['feedforward loop', 'feedforward maximum',
#        'feedforward maximum power point tracking',
#        'fuzzy feedforward peak power tracking effectiveness', 'neural',
#        'proportional plus integral', 'pv systems', 'reference voltage',
#        'solar cell array', 'solar insolation', 'tracking', 'voltage'],
#       dtype='<U51'), array(['average transfer rate', 'high information transfer rate',
#        'high transfer rates', 'mobile phone',
#        'noninvasive signal recording', 'phone numbers',
#        'virtual telephone keypad'], dtype='<U30'), array(['dissipation', 'tag', 'tag sense amplifiers'], dtype='<U20'), array(['controlled', 'hardware measurements', 'load variations',
#        'microcontroller', 'photovoltaic power inverter',
#        'robust fuzzy controlled', 'robust fuzzy controller',
#        'taguchi method', 'taguchi tuned scaling factors',
#        'transient response'], dtype='<U29'), array(['embedded dram', 'embedded dram macros', 'embedded memory logic',
#        'mobile personal digital assistant', 'pda chip', 'rendering'],
#       dtype='<U33'), array(['attenuation effect', 'basis function network',
#        'external disturbances', 'friction force', 'learning',
#        'learning feedback component', 'linear brushless dc motors',
#        'linear brushless motors', 'linear model', 'linear motors',
#        'motion control', 'nonlinear friction force', 'payload variation',
#        'position tracking', 'robust wavelet neuro control',
#        'stability robustness', 'state feedback component', 'wavelet',
#        'wavelet neural network', 'wavelet neural networks'], dtype='<U28'), array(['accountability', 'automatic teller machine', 'ballot box',
#        'canada', 'electronic voting systems', 'internet',
#        'lever machines', 'paper', 'polls', 'sale', 'united states',
#        'voting issues'], dtype='<U25'), array(['dirichlet distributions', 'finite state markov chain',
#        'hybrid systems', 'maneuvering', 'marginal posterior distribution',
#        'multiple switching models', 'random transition probabilities',
#        'recursive hybrid state estimation', 'recursive state estimation',
#        'regime variable', 'regime variables', 'tracking',
#        'transition probabilities'], dtype='<U33'), array(['matlab code', 'pedagogical tool', 'plotting ambiguity functions',
#        'pulse compression', 'radar courses', 'radar signals',
#        'sparse matrix operations'], dtype='<U28'), array(['background knowledge', 'inductive logic programming',
#        'navigation', 'spatial knowledge', 'spatial relations'],
#       dtype='<U27'), array(['bayesian nonstationary autoregressive models',
#        'biomedical signal analysis', 'linear dynamical system',
#        'multivariate autoregressive model',
#        'nonstationary multivariate signals', 'photic synchronization',
#        'real electroencephalogram data', 'scenarios',
#        'variational bayesian algorithm'], dtype='<U44'), array(['accessibility barriers', 'attitudinal barriers', 'children',
#        'desktop virtual reality', 'disability awareness',
#        'mobility impairments', 'virtual wheelchair experience', 'youth'],
#       dtype='<U29'), array(['incremental motion control', 'linear synchronous motor',
#        'multisegment sliding mode control', 'multisegment switching',
#        'permanent magnet linear synchronous motor',
#        'pmlsm servo drive system', 'servo',
#        'trapezoidal velocity profile'], dtype='<U41'), array(['coupling capacitors', 'internal voltage', 'level shifter',
#        'low noise', 'low ripple voltage', 'negative erasing voltage',
#        'operating voltage'], dtype='<U24'), array(['handwritten text', 'microsoft', 'pdas',
#        'pocket pc operating system'], dtype='<U26'), array(['frequency acquisition', 'operating frequencies'], dtype='<U21'), array(['arterial blood pressure fluctuations', 'autoregulation',
#        'blood flow', 'clear difference', 'complexity', 'dynamics',
#        'forced', 'hypertensive', 'hypertensive blood flow recordings',
#        'hypertensive rats', 'hypertensive recordings', 'kidney',
#        'multiresolution wavelet transform', 'myogenic', 'normotensive',
#        'rats', 'renal', 'renal autoregulation',
#        'renal autoregulatory mechanisms', 'renal blood flow',
#        'renyi entropy', 'spontaneous arterial pressure fluctuations',
#        'spontaneous oscillations', 'spontaneously hypertensive rats',
#        'tubuloglomerular'], dtype='<U42'), array(['attainable sky coverage', 'attitude determination accuracy',
#        'boresight axis', 'charge coupled', 'inertial pointing',
#        'initial attitude acquisition', 'minimum star brightness',
#        'photodetector', 'reliability',
#        'star catalog generation preprocessing', 'star tracker',
#        'star trackers'], dtype='<U37'), array(['control theory', 'design pid controllers',
#        'maclaurin pid controller', 'nominal stable process',
#        'nominal system', 'overshoot', 'process control systems',
#        'resonance peak', 'rise time', 'stability margin',
#        'suboptimal controllers', 'suboptimal pid controller',
#        'time delay'], dtype='<U25'), array(['costs', 'flyback converter', 'power supply design',
#        'power supply engineer', 'prototyping', 'system performance'],
#       dtype='<U21')]
