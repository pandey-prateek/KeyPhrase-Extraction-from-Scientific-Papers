# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install keybert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keybert in /usr/local/lib/python3.9/dist-packages (0.7.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.9/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.9/dist-packages (from keybert) (13.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from keybert) (1.22.4)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.9/dist-packages (from keybert) (2.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.4.0->keybert) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.4.0->keybert) (2.14.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2->keybert) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2->keybert) (1.1.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.65.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.26.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.14.1+cu116)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.1.97)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert) (1.13.1+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.7)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.25.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (8.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (1.26.15)

# %%
pip install jedi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jedi in /usr/local/lib/python3.9/dist-packages (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi) (0.8.3)

# %%
# %cd gdrive/MyDrive/scienceie_drive/
# %ls
# Out:
# /content/gdrive/MyDrive/scienceie_drive
# scienceie2017_dev/      scienceie2017_train/
# scienceie2017_scripts/  semeval_articles_test/

# %%
import os
from collections import defaultdict
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import re
from keybert import KeyBERT

def preprocess (text):
    text = text.lower ()

    text = re.sub ('(\\d|\\W)+', ' ', text)
    text = re.sub ('\d+(\.\d*)?', ' ', text)
    split_text = text.split ()

    split_text = [word for word in split_text if len (word) > 3]
    text = ' '.join (split_text)
    return text

def extract_topn (feature_names, text, topn = 15):
    text = text [:topn]
    scores = []
    features = []

    for index, score in text:
        scores.append (round (score, 3))
        features.append (feature_names [index])

    results = []

    for index in range (len (features)):
        results.append (features [index])
    
    return results

# Folder Path

# Read text File
def read_text_file(file_path):
    with open(file_path, 'r') as f:
        return f.read()

def read_ann_file(file_path):
    with open(file_path, 'r') as f:
        l=[]
        for line in f.readlines():
            l.append(line[:-1].split('\t') [-1])
        return l
        # data[name.split('.')[0]].append(l)
  
  
# iterate through all file

def load_data (path):  
    data=defaultdict(dict)  

    for file in os.listdir(path):
        # Check whether file is in text format or not
        
        name=file.split('.')[0]
        if file.endswith(".txt"):
            file_path = path + file
            data[name]['text']=read_text_file(file_path)
        if file.endswith(".ann"):
            file_path = path + file
            # call read text file function
            data[name]['ann']=read_ann_file(file_path)
    return data

train_data = load_data ('./scienceie2017_train/train2/')
train_text = []
for i in train_data.keys ():
    train_text.append (train_data [i]['text'])

train_text = [text.strip ('\n') for text in train_text]

test_text = []
y_test = []

test_data = load_data ('./semeval_articles_test/')

for i in test_data.keys ():
    test_text.append (test_data [i]['text'])
    y_test.append (test_data [i]['ann'])

test_text = [text.strip ('\n') for text in test_text]

train_text = [preprocess (text) for text in train_text]
test_text = [preprocess (text) for text in test_text]


y_hat = []

kw_model = KeyBERT ()

y_hat = kw_model.extract_keywords (docs=test_text, keyphrase_ngram_range = (1, 3))
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
elements = []
for ele in y_hat:
  sub_ele = []
  for item in ele:
    sub_ele.append (item [0])
  elements.append (sub_ele)

y_hat = elements

print (y_hat)
# Out:
# [['momentum fourier basis', 'boundary region modelled', 'boundary basis suitable', 'boundary basis', 'parametrise boundary region'], ['throughput materials science', 'materials science', 'properties simulation provenance', 'throughput materials', 'database scientific'], ['routing protocol mwsns', 'routing protocol phaser', 'multihop routing protocol', 'proposed multihop routing', 'multipath routing solution'], ['allocated lanes based', 'lane selection policy', 'specify probabilistic routing', 'probabilistic routing defined', 'routes piecewise technique'], ['stability discretisation discussion', 'stability discretisation', 'stability lagrange multiplier', 'displacement constraint saddle', 'stiffness matrix unconstrained'], ['cardiac geometry meshes', 'finite element method', 'heart geometries systems', 'realistic cardiac geometry', 'space realistic cardiac'], ['modulus asphaltic samples', 'stiffness modulus asphaltic', 'tests optimum bitumen', 'asphaltic samples', 'asphaltic samples including'], ['total focusing method', 'focusing method beam', 'beam synthetically focused', 'focusing method', 'focused point target'], ['upgrade process technology', 'process technology reduces', 'differences technology scale', 'batches process technology', 'differences technology'], ['numerical simulation flow', 'simulation flow trivial', 'simulation flow', 'carlo method dsmc', 'direct simulation monte'], ['particle cohesion modelled', 'packing flow granular', 'particle contacts zoning', 'applied particle cohesion', 'flow granular materials'], ['genetic algorithm global', 'genetic algorithm', 'maxima genetic algorithm', 'genetic algorithm repeatedly', 'algorithm global optimisation'], ['oscillations kernel functions', 'oscillations introduced kernel', 'oscillations kernel', 'introduced kernel interpolation', 'kernel interpolation functions'], ['water efficiency chemical', 'aquarium chemical reaction', 'efficiency aquarium chemical', 'chemical reaction water', 'water chemical reaction'], ['maintained pill temperature', 'pill assessed thermal', 'pill temperature millikelvin', 'pill temperature', 'pill allows thermal'], ['blood flow solver', 'boltzmann solvers performance', 'performance analysis blood', 'analysis blood flow', 'lattice boltzmann solvers'], ['crystal plasticity model', 'parameters crystal plasticity', 'nickel based superalloy', 'deformation fatigue crack', 'plasticity model combination'], ['shear stress profiles', 'velocity shear stress', 'resolve velocity shear', 'shear stress', 'stress profiles velocity'], ['fluorescent rhodamine dyes', 'properties fluorescent rhodamine', 'geometries rhodamine dyes', 'rhodamine dyes known', 'dyes rhodamines known'], ['virtualization technologies choosing', 'virtualization technologies', 'virtualization', 'virtualized', 'introduced virtualization'], ['corrosion alloy', 'corrosion behaviour alloy', 'particle important corrosion', 'localized corrosion alloy', 'important corrosion behaviour'], ['numerical bifurcation analysis', 'petsc implementation', 'bifurcation analysis references', 'extended dynamical systems', 'petsc implementation consists'], ['fabhemelb python tool', 'simulation workflows fabhemelb', 'general fabhemelb commands', 'automate construction management', 'fabhemelb help automate'], ['time frequency spectrogram', 'methods stft spectrogram', 'stft spectrogram utilised', 'frequency spectrogram', 'stft spectrogram'], ['solar conversion efficiency', 'solar conversion', 'conversion incident solar', 'losses limit solar', 'energy conversion technologies'], ['kutta imex schemes', 'atmospheric motion', 'runge kutta', 'atmospheric motion tested', 'equations governing atmospheric'], ['discretisation errors smooth', 'spatial discretisation errors', 'high order discretisation', 'discretisation errors', 'curvilinear mesh applications'], ['ferromagnetism nickel', 'ferromagnetism nickel accounted', 'purposes ferromagnetism nickel', 'electronic structure alloy', 'lattice constant alloying'], ['maximum n ...

# %%
cnt = 0

for i in range (len (y_test)):
    for word in y_test [i]:
        if word in y_hat [i]:
            print (word)
            cnt += 1

print ("Exact keyword matches ", cnt)
# Out:
# multihop routing protocol
# multihop routing protocol
# lane selection policy
# finite element method
# cardiac geometry meshes
# asphaltic samples
# asphaltic samples
# asphaltic samples
# asphaltic samples
# asphaltic samples
# asphaltic samples
# genetic algorithm
# genetic algorithm
# kernel interpolation functions
# aquarium chemical reaction
# crystal plasticity model
# virtualization technologies
# virtualization technologies
# numerical bifurcation analysis
# solar conversion
# atmospheric motion
# magnetic phase transition
# uranium superconductors
# contact surface scheme
# contact surface method
# tungsten heat switches
# tungsten heat switches
# eddy current probe
# nodes mobility
# mesoporous silica
# polymer chains
# soil moisture prediction
# sentence alignment
# sentence alignment
# landcover projections
# cerebral angiography
# piezoelectric load cell
# face recognition
# polymer chains
# anodizing coatings
# anodizing coatings
# milled nanocrystalline powders
# aluminum alloy powders
# scanning electron microscopes
# scanning electron microscopy
# cosmology
# cluster breakup
# tubular composites failure
# traditional digital photogrammetry
# magnetic lenses
# neutrino magnetic moment
# Exact keyword matches  51
